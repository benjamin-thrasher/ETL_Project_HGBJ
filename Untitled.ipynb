# %%
import pandas as pd

# %%
pitching_df = pd.read_csv('pitching.csv')

# %%
pitching_df.head()
# Out:
#     playerID  yearID  stint teamID lgID   W   L   G  GS  CG  ...  IBB  WP  \
# 0  spaldal01    1871      1    BS1  NaN  19  10  31  31  22  ...  NaN NaN
# 1  mcbridi01    1871      1    PH1  NaN  18   5  25  25  25  ...  NaN NaN
# 2  zettlge01    1871      1    CH1  NaN  18   9  28  28  25  ...  NaN NaN
# 3  woltery01    1871      1    NY2  NaN  16  16  32  32  31  ...  NaN NaN
# 4  brainas01    1871      1    WS3  NaN  12  15  30  30  30  ...  NaN NaN
#
#    HBP  BK  BFP  GF    R  SH  SF  GIDP
# 0  NaN   0  NaN NaN  272 NaN NaN   NaN
# 1  NaN   0  NaN NaN  223 NaN NaN   NaN
# 2  NaN   0  NaN NaN  233 NaN NaN   NaN
# 3  NaN   0  NaN NaN  283 NaN NaN   NaN
# 4  NaN   0  NaN NaN  292 NaN NaN   NaN
#
# [5 rows x 30 columns]

# %%
min_pitching_df = pitching_df[["playerID", "yearID", "teamID", "W", "L", "G", "GS", "CG", "SHO", "SV", "H", "ER", "HR", "BB", "SO", "ERA", "IBB", "WP", "HBP"]]

min_pitching_df.head()
# Out:
#     playerID  yearID teamID   W   L   G  GS  CG  SHO  SV    H   ER  HR  BB  \
# 0  spaldal01    1871    BS1  19  10  31  31  22    1   0  333   96   2  38
# 1  mcbridi01    1871    PH1  18   5  25  25  25    0   0  285  113   3  40
# 2  zettlge01    1871    CH1  18   9  28  28  25    0   0  298   73   6  25
# 3  woltery01    1871    NY2  16  16  32  32  31    1   0  345  108   7  39
# 4  brainas01    1871    WS3  12  15  30  30  30    0   0  361  132   4  37
#
#    SO   ERA  IBB  WP  HBP
# 0  23  3.36  NaN NaN  NaN
# 1  15  4.58  NaN NaN  NaN
# 2  22  2.73  NaN NaN  NaN
# 3  22  3.43  NaN NaN  NaN
# 4  13  4.50  NaN NaN  NaN

# %%
ren_min_pitching_df = min_pitching_df.rename(columns={"playerID":"Player ID",
                                            "yearID": "Year", 
                                            "teamID": "Team", 
                                            "W": "Wins", 
                                            "L": "Losses", 
                                            "G": "Games", 
                                            "GS": "Games Started",
                                            "CG": "Complete Games", 
                                            "SHO": "Shut Outs", 
                                            "SV": "Saves", 
                                            "H": "Hits", 
                                            "ER": "Earnded Runs", 
                                            "HR": "Home Runs", 
                                            "BB": "Walks",
                                            "SO": "Strike Outs", 
                                            "ERA": "Earned Run Average",
                                            "IBB": "Intentional Walks",
                                            "WP": "Wild Pitch",
                                            "HBP": "Hit by Pitch",
                                           })
ren_min_pitching_df.head()
# Out:
#    Player ID  Year Team  Wins  Losses  Games  Games Started  Complete Games  \
# 0  spaldal01  1871  BS1    19      10     31             31              22
# 1  mcbridi01  1871  PH1    18       5     25             25              25
# 2  zettlge01  1871  CH1    18       9     28             28              25
# 3  woltery01  1871  NY2    16      16     32             32              31
# 4  brainas01  1871  WS3    12      15     30             30              30
#
#    Shut Outs  Saves  Hits  Earnded Runs  Home Runs  Walks  Strike Outs  \
# 0          1      0   333            96          2     38           23
# 1          0      0   285           113          3     40           15
# 2          0      0   298            73          6     25           22
# 3          1      0   345           108          7     39           22
# 4          0      0   361           132          4     37           13
#
#    Earned Run Average  Intentional Walks  Wild Pitch  Hit by Pitch
# ...
