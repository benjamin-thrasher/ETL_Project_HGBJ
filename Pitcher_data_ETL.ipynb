# %%
import pandas as pd
from sqlalchemy import create_engine
import psycopg2

# %%
franchise_file = "Resources/TeamsFranchises.csv"
franchise_df = pd.read_csv(franchise_file)
franchise_df.head()

teams_file = "Resources/Teams.csv"
teams_df = pd.read_csv(teams_file)
teams_df.head()
filtered_teams_df = teams_df.loc[(teams_df['yearID'] >= 2000) & (teams_df['yearID'] <= 2015)]
filtered_teams_df_clean = filtered_teams_df[["yearID", "teamID", "lgID", "franchID", "G", "W", "L"]]
filtered_teams_df_renamed = filtered_teams_df_clean.rename(columns={ 'yearID' : 'yearid',
                                                                     'teamID' : 'teamid',
                                                                    'lgID' : 'leagueid',
                                                                    'franchID': 'franchid',
                                                                    'G':'games',
                                                                    'W':"wins",
                                                                    "L":'losses'
                                                                   })

pitcher_file = "Resources/Pitching.csv"
pitcher_df = pd.read_csv(pitcher_file)
pitcher_df.head()
# filtered_pitcher_df_renamed
# Out:
#     playerID  yearID teamID lgID  W  L   G  IPouts
# 0  aardsda01    2004    SFN   NL  1  0  11      32
# 1  aardsda01    2006    CHN   NL  3  0  45     159
# 2  aardsda01    2007    CHA   AL  2  1  25      97
# 3  aardsda01    2008    BOS   AL  4  2  47     146
# 4  aardsda01    2009    SEA   AL  3  6  73     214

# %%
franchise_df_clean = franchise_df[["franchID", "franchName", "active"]]
franchise_df_clean
# Out:
#     franchID                     franchName active
# 0        ALT          Altoona Mountain City      N
# 1        ANA  Los Angeles Angels of Anaheim      Y
# 2        ARI           Arizona Diamondbacks      Y
# 3        ATH         Philadelphia Athletics      N
# 4        ATL                 Atlanta Braves      Y
# ..       ...                            ...    ...
# 115      WNL           Washington Nationals      N
# 116      WNT           Washington Nationals    NaN
# 117      WOR            Worcester Ruby Legs      N
# 118      WSN           Washington Nationals      Y
# 119      WST           Washington Statesmen      N
#
# [120 rows x 3 columns]

# %%
franchise_df_renamed = franchise_df_clean.rename(columns={ 'franchID' : 'franchid',
                                                           'franchName' : 'franchname'})

franchise_df_renamed
# Out:
#     franchid                     franchname active
# 0        ALT          Altoona Mountain City      N
# 1        ANA  Los Angeles Angels of Anaheim      Y
# 2        ARI           Arizona Diamondbacks      Y
# 3        ATH         Philadelphia Athletics      N
# 4        ATL                 Atlanta Braves      Y
# ..       ...                            ...    ...
# 115      WNL           Washington Nationals      N
# 116      WNT           Washington Nationals    NaN
# 117      WOR            Worcester Ruby Legs      N
# 118      WSN           Washington Nationals      Y
# 119      WST           Washington Statesmen      N
#
# [120 rows x 3 columns]

# %%
connection_string = "postgres:Sania0817@localhost:5433/BaseballStats_DB"
engine = create_engine(f'postgresql://{connection_string}')

# %%
franchise_df_renamed.to_sql(name='franchise', con=engine, if_exists='append', index=False)
filtered_teams_df_renamed.to_sql(name='teams', con=engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# UniqueViolation                           Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1684                 if not evt_handled:
# -> 1685                     self.dialect.do_executemany(
#    1686                         cursor, statement, parameters, context
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/dialects/postgresql/psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     902             xtras = self._psycopg2_extras()
# --> 903             context._psycopg2_fetched_rows = xtras.execute_values(
#     904                 cursor,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/psycopg2/extras.py in execute_values(cur, sql, argslist, template, page_size, fetch)
#    1269         parts[-1:] = post
# -> 1270         cur.execute(b''.join(parts))
#    1271         if fetch:
#
# UniqueViolation: duplicate key value violates unique constraint "franchise_pkey"
# DETAIL:  Key (franchid)=(ALT) already exists.
#
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# <ipython-input-17-e0202075b340> in <module>
# ----> 1 franchise_df_renamed.to_sql(name='franchise', con=engine, if_exists='append', index=False)
#       2 filtered_teams_df_renamed.to_sql(name='teams', con=engine, if_exists='append', index=False)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2777         from pandas.io import sql
#    2778
# -> 2779         sql.to_sql(
#    2780             self,
#    2781             name,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     599         )
#     600
# --> 601     pandas_sql.to_sql(
#     602         frame,
#     603         name,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1417                 raise ValueError("inf cannot be used with MySQL") from err
#    1418             else:
# -> 1419                 raise err
#    1420
#    1421         if not name.isdigit() and not name.islower():
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1409
#    1410         try:
# -> 1411             table.insert(chunksize, method=method)
#    1412         except exc.SQLAlchemyError as err:
#    1413             # GH34431
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/sql.py in insert(self, chunksize, method)
#     843
#     844                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 845                 exec_insert(conn, keys, chunk_iter)
#     846
#     847     def _query_iterator(
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/sql.py in _execute_insert(self, conn, keys, data_iter)
#     760         """
#     761         data = [dict(zip(keys, row)) for row in data_iter]
# --> 762         conn.execute(self.table.insert(), data)
#     763
#     764     def _execute_insert_multi(self, conn, keys, data_iter):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py in execute(self, statement, *multiparams, **params)
#    1198             )
#    1199         else:
# -> 1200             return meth(self, multiparams, params, _EMPTY_EXECUTION_OPTS)
#    1201
#    1202     def _execute_function(self, func, multiparams, params, execution_options):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/sql/elements.py in _execute_on_connection(self, connection, multiparams, params, execution_options, _force)
#     311     ):
#     312         if _force or self.supports_execution:
# --> 313             return connection._execute_clauseelement(
#     314                 self, multiparams, params, execution_options
#     315             )
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_clauseelement(self, elem, multiparams, params, execution_options)
#    1387             linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1388         )
# -> 1389         ret = self._execute_context(
#    1390             dialect,
#    1391             dialect.execution_ctx_cls._init_compiled,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1746
#    1747         except BaseException as e:
# -> 1748             self._handle_dbapi_exception(
#    1749                 e, statement, parameters, cursor, context
#    1750             )
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1927                 util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    1928             elif should_wrap:
# -> 1929                 util.raise_(
#    1930                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1931                 )
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     209
#     210         try:
# --> 211             raise exception
#     212         finally:
#     213             # credit to
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1683                             break
#    1684                 if not evt_handled:
# -> 1685                     self.dialect.do_executemany(
#    1686                         cursor, statement, parameters, context
#    1687                     )
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/dialects/postgresql/psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     901                 kwargs = {}
#     902             xtras = self._psycopg2_extras()
# --> 903             context._psycopg2_fetched_rows = xtras.execute_values(
#     904                 cursor,
#     905                 statement,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/psycopg2/extras.py in execute_values(cur, sql, argslist, template, page_size, fetch)
#    1268             parts.append(b',')
#    1269         parts[-1:] = post
# -> 1270         cur.execute(b''.join(parts))
#    1271         if fetch:
#    1272             result.extend(cur.fetchall())
#
# IntegrityError: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "franchise_pkey"
# DETAIL:  Key (franchid)=(ALT) already exists.
#
# [SQL: INSERT INTO franchise (franchid, franchname, active) VALUES (%(franchid)s, %(franchname)s, %(active)s)]
# [parameters: ({'franchid': 'ALT', 'franchname': 'Altoona Mountain City', 'active': 'N'}, {'franchid': 'ANA', 'franchname': 'Los Angeles Angels of Anaheim', 'active': 'Y'}, {'franchid': 'ARI', 'franchname': 'Arizona Diamondbacks', 'active': 'Y'}, {'franchid': 'ATH', 'franchname': 'Philadelphia Athletics', 'active': 'N'}, {'franchid': 'ATL', 'franchname': 'Atlanta Braves', 'active': 'Y'}, {'franchid': 'BAL', 'franchname': 'Baltimore Orioles', 'active': 'Y'}, {'franchid': 'BFB', 'franchname': 'Buffalo Bisons', 'active': 'N'}, {'franchid': 'BFL', 'franchname': 'Buffalo Bisons', 'active': 'N'}  ... displaying 10 of 120 total bound parameter sets ...  {'franchid': 'WSN', 'franchname': 'Washington Nationals', 'active': 'Y'}, {'franchid': 'WST', 'franchname': 'Washington Statesmen', 'active': 'N'})]
# (Background on this error at: http://sqlalche.me/e/14/gkpj)
